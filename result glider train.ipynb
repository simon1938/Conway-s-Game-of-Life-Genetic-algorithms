# %%
# !git clone https://github.com/simon1938/Conway-s-Game-of-Life-Genetic-algorithms.git
# %cd Conway-s-Game-of-Life-Genetic-algorithms
# Out:
# Cloning into 'Conway-s-Game-of-Life-Genetic-algorithms'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 98 (delta 37), reused 80 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 845.55 KiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/Conway-s-Game-of-Life-Genetic-algorithms

# %%
# !python game_of_life.py train --cells 200 --training_attempts 150 --steps 60 --grid_file best_positions.json

# %%
# !python game_of_life.py train --cells 100 --training_attempts 200 --steps 40 --grid_file best_positions.json
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Starting training...
# Initial cells: 100
# Evolution steps: 40
# Generating initial population...
# Loaded 100 positions from best_positions.json
# Generation 0: Best Fitness = 1960.31
# Generation 1: Best Fitness = 1960.31
# Generation 2: Best Fitness = 1960.31
# Generation 3: Best Fitness = 1960.31
# Generation 4: Best Fitness = 1960.31
# Generation 5: Best Fitness = 1960.31
# Generation 6: Best Fitness = 1960.31
# Generation 7: Best Fitness = 1988.10
# Generation 8: Best Fitness = 1988.10
# Generation 9: Best Fitness = 1988.10
# Generation 10: Best Fitness = 1988.10
# Generation 11: Best Fitness = 1988.10
# Generation 12: Best Fitness = 1988.10
# Generation 13: Best Fitness = 1988.10
# Generation 14: Best Fitness = 1988.10
# Generation 15: Best Fitness = 1988.10
# Generation 16: Best Fitness = 1988.10
# Generation 17: Best Fitness = 1988.10
# Generation 18: Best Fitness = 1988.10
# Generation 19: Best Fitness = 1988.10
# Generation 20: Best Fitness = 1988.10
# Generation 21: Best Fitness = 1988.10
# Generation 22: Best Fitness = 1988.10
# Generation 23: Best Fitness = 1988.10
# Generation 24: Best Fitness = 1988.10
# Generation 25: Best Fitness = 1988.10
# Generation 26: Best Fitness = 1988.10
# Generation 27: Best Fitness = 1988.10
# Generation 28: Best Fitness = 1988.10
# Generation 29: Best Fitness = 1988.10
# Generation 30: Best Fitness = 1988.10
# Generation 31: Best Fitness = 1988.10
# Generation 32: Best Fitness = 1988.10
# Generation 33: Best Fitness = 1988.10
# Generation 34: Best Fitness = 1988.10
# Generation 35: Best Fitness = 1988.10
# Generation 36: Best Fitness = 1988.10
# Generation 37: Best Fitness = 1988.10
# Generation 38: Best Fitness = 1988.10
# Generation 39: Best Fitness = 1988.10
# Generation 40: Best Fitness = 1988.10
# Generation 41: Best Fitness = 1988.10
# Generation 42: Best Fitness = 1988.10
# Generation 43: Best Fitness = 1988.10
# Generation 44: Best Fitness = 1988.10
# Generation 45: Best Fitness = 1988.10
# Generation 46: Best Fitness = 1988.10
# Generation 47: Best Fitness = 1988.10
# Generation 48: Best Fitness = 1988.10
# Generation 49: Best Fitness = 1988.10
# Generation 50: Best Fitness = 1988.10
# Generation 51: Best Fitness = 1988.10
# Generation 52: Best Fitness = 1988.10
# Generation 53: Best Fitness = 1988.10
# Generation 54: Best Fitness = 1988.10
# Generation 55: Best Fitness = 1988.10
# Generation 56: Best Fitness = 1988.10
# Generation 57: Best Fitness = 1988.10
# Generation 58: Best Fitness = 1988.10
# Generation 59: Best Fitness = 1988.10
# Generation 60: Best Fitness = 1988.10
# Generation 61: Best Fitness = 1988.10
# Generation 62: Best Fitness = 1988.10
# Generation 63: Best Fitness = 1988.10
# Generation 64: Best Fitness = 1988.10
# Generation 65: Best Fitness = 1988.10
# Generation 66: Best Fitness = 1988.10
# Generation 67: Best Fitness = 1988.10
# Generation 68: Best Fitness = 1988.10
# Generation 69: Best Fitness = 1988.10
# Generation 70: Best Fitness = 1988.10
# Generation 71: Best Fitness = 1988.10
# Generation 72: Best Fitness = 1988.10
# Generation 73: Best Fitness = 1988.10
# Generation 74: Best Fitness = 1988.10
# Generation 75: Best Fitness = 1988.10
# Generation 76: Best Fitness = 1988.10
# Generation 77: Best Fitness = 1988.10
# Generation 78: Best Fitness = 1988.10
# Generation 79: Best Fitness = 1988.10
# Generation 80: Best Fitness = 1988.10
# Generation 81: Best Fitness = 1988.10
# Generation 82: Best Fitness = 1988.10
# Generation 83: Best Fitness = 1988.10
# Generation 84: Best Fitness = 1988.10
# Generation 85: Best Fitness = 1988.10
# Generation 86: Best Fitness = 1988.10
# Generation 87: Best Fitness = 1988.10
# Generation 88: Best Fitness = 1988.10
# Generation 89: Best Fitness = 1988.10
# Generation 90: Best Fitness = 1988.10
# Generation 91: Best Fitness = 1988.10
# Generation 92: Best Fitness = 1988.10
# Generation 93: Best Fitness = 1988.10
# Generation 94: Best Fitness = 1988.10
# Generation 95: Best Fitness = 1988.10
# Generation 96: Best Fitness = 1988.10
# Generation 97: Best Fitness = 1988.10
# Generation 98: Best Fitness = 1988.10
# Generation 99: Best Fitness = 1988.10
# Generation 100: Best Fitness = 1988.10
# Generation 101: Best Fitness = 1988.10
# Generation 102: Best Fitness = 1988.10
# Generation 103: Best Fitness = 1988.10
# Generation 104: Best Fitness = 1988.10
# Generation 105: Best Fitness = 1988.10
# Generation 106: Best Fitness = 1988.10
# Generation 107: Best Fitness = 1988.10
# Generation 108: Best Fitness = 1988.10
# Generation 109: Best Fitness = 1988.10
# Generation 110: Best Fitness = 1988.10
# Generation 111: Best Fitness = 1988.10
# Generation 112: Best Fitness = 1988.10
# Generation 113: Best Fitness = 1988.10
# Generation 114: Best Fitness = 1988.10
# Generation 115: Best Fitness = 1988.10
# Generation 116: Best Fitness = 1988.10
# Generation 117: Best Fitness = 1988.10
# Generation 118: Best Fitness = 1988.10
# Generation 119: Best Fitness = 1988.10
# Generation 120: Best Fitness = 1988.10
# Generation 121: Best Fitness = 1988.10
# Generation 122: Best Fitness = 1988.10
# Generation 123: Best Fitness = 1988.10
# Generation 124: Best Fitness = 1988.10
# Generation 125: Best Fitness = 1988.10
# Generation 126: Best Fitness = 1988.10
# Generation 127: Best Fitness = 1988.10
# Generation 128: Best Fitness = 1988.10
# Generation 129: Best Fitness = 1988.10
# Generation 130: Best Fitness = 1988.10
# Generation 131: Best Fitness = 1988.10
# Generation 132: Best Fitness = 1988.10
# Generation 133: Best Fitness = 1988.10
# Generation 134: Best Fitness = 1988.10
# Generation 135: Best Fitness = 1988.10
# Generation 136: Best Fitness = 1988.10
# Generation 137: Best Fitness = 1988.10
# Generation 138: Best Fitness = 1988.10
# Generation 139: Best Fitness = 1988.10
# Generation 140: Best Fitness = 1988.10
# Generation 141: Best Fitness = 1988.10
# Generation 142: Best Fitness = 1988.10
# Generation 143: Best Fitness = 1988.10
# Generation 144: Best Fitness = 1988.10
# Generation 145: Best Fitness = 1988.10
# Generation 146: Best Fitness = 1988.10
# Generation 147: Best Fitness = 1988.10
# Generation 148: Best Fitness = 1988.10
# Generation 149: Best Fitness = 1988.10
# Generation 150: Best Fitness = 1988.10
# Generation 151: Best Fitness = 1988.10
# Generation 152: Best Fitness = 1988.10
# Generation 153: Best Fitness = 1988.10
# Generation 154: Best Fitness = 1988.10
# Generation 155: Best Fitness = 1988.10
# Generation 156: Best Fitness = 1988.10
# Generation 157: Best Fitness = 1988.10
# Generation 158: Best Fitness = 1988.10
# Generation 159: Best Fitness = 1988.10
# Generation 160: Best Fitness = 1988.10
# Generation 161: Best Fitness = 1988.10
# Generation 162: Best Fitness = 1988.10
# Generation 163: Best Fitness = 1988.10
# Generation 164: Best Fitness = 1988.10
# Generation 165: Best Fitness = 1988.10
# Generation 166: Best Fitness = 1988.10
# Generation 167: Best Fitness = 1988.10
# Generation 168: Best Fitness = 1988.10
# Generation 169: Best Fitness = 1988.10
# Generation 170: Best Fitness = 1988.10
# Generation 171: Best Fitness = 1988.10
# Generation 172: Best Fitness = 1988.10
# Generation 173: Best Fitness = 1988.10
# Generation 174: Best Fitness = 1988.10
# Generation 175: Best Fitness = 1988.10
# Generation 176: Best Fitness = 1988.10
# Generation 177: Best Fitness = 1988.10
# Generation 178: Best Fitness = 1988.10
# Generation 179: Best Fitness = 1988.10
# Generation 180: Best Fitness = 1988.10
# Generation 181: Best Fitness = 1988.10
# Generation 182: Best Fitness = 1988.10
# Generation 183: Best Fitness = 1988.10
# Generation 184: Best Fitness = 1988.10
# Generation 185: Best Fitness = 1988.10
# Generation 186: Best Fitness = 2000.11
# Generation 187: Best Fitness = 2000.11
# Generation 188: Best Fitness = 2000.11
# Generation 189: Best Fitness = 2000.11
# Generation 190: Best Fitness = 2000.11
# Generation 191: Best Fitness = 2000.11
# Generation 192: Best Fitness = 2000.11
# Generation 193: Best Fitness = 2000.11
# Generation 194: Best Fitness = 2000.11
# Generation 195: Best Fitness = 2000.11
# Generation 196: Best Fitness = 2000.11
# Generation 197: Best Fitness = 2000.11
# Generation 198: Best Fitness = 2000.11
# Generation 199: Best Fitness = 2000.11
#
# Training completed!
# Best fitness found: 2000.11
# Args: cells=100, training_attempts=200, steps=40, grid_file=best_positions.json
# Saving 100 positions to best_positions.json
# Training history saved to training_history_20250110_155439.json
# Training config saved to config_train.json

# %%
# Imports
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import os

# Configuration style des plots
plt.style.use('default')  # On utilise le style par défaut de matplotlib
sns.set_theme()  # On applique le thème seaborn par dessus
plt.rcParams['figure.figsize'] = [12, 6]

# Chargement des données
def load_training_data(history_file):
    """Charge les données d'entraînement depuis un fichier"""
    with open(history_file, 'r') as f:
        data = json.load(f)
    return data

# Cherche le fichier d'historique le plus récent
history_files = glob('training_history_*.json')
latest_file = max(history_files, key=os.path.getctime)
training_data = load_training_data(latest_file)

# Charge aussi la config
with open('config_train.json', 'r') as f:
    config_data = json.load(f)

print(f"Fichier analysé: {latest_file}")
print("\nParamètres d'entraînement:")
for k, v in config_data['training_params'].items():
    print(f"{k}: {v}")
# Out:
# Fichier analysé: training_history_20250110_155439.json
#
# Paramètres d'entraînement:
# population_size: 10
# num_generations: 200
# mutation_rate: 0.1
# elite_size: 2
# initial_cells: 100
# evolution_steps: 40
# grid_width: 80
# grid_height: 60
# grid_file: best_positions.json

# %%
# Plot de l'évolution de la fitness
def plot_fitness_evolution(data):
    generations = range(len(data['best_fitness_per_gen']))

    fig, ax = plt.subplots(figsize=(14, 7))

    # Plot meilleure fitness et moyenne
    ax.plot(generations, data['best_fitness_per_gen'], 'b-', label='Meilleure Fitness', linewidth=2)
    ax.plot(generations, data['avg_fitness_per_gen'], 'r--', label='Fitness Moyenne', linewidth=2)

    # Ajout zone de variance
    fitness_std = [np.std(gen_fitness) for gen_fitness in data['fitness_history']]
    ax.fill_between(generations,
                    np.array(data['avg_fitness_per_gen']) - fitness_std,
                    np.array(data['avg_fitness_per_gen']) + fitness_std,
                    alpha=0.2, color='gray', label='±1 Écart-type')

    ax.set_title('Évolution de la Fitness au Cours des Générations', fontsize=14)
    ax.set_xlabel('Génération', fontsize=12)
    ax.set_ylabel('Fitness', fontsize=12)
    ax.grid(True, alpha=0.3)
    ax.legend(fontsize=10)

    plt.tight_layout()
    plt.show()

plot_fitness_evolution(training_data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def plot_fitness_distribution(data):
    # Sélectionner la première et la dernière génération
    first_gen = data['fitness_history'][0]
    last_gen = data['fitness_history'][-1]

    # Créer un DataFrame avec ces deux générations
    generations = ['Première Génération'] * len(first_gen) + ['Dernière Génération'] * len(last_gen)
    fitness_values = first_gen + last_gen

    df = pd.DataFrame({
        'Génération': generations,
        'Fitness': fitness_values
    })

    # Plot violin
    plt.figure(figsize=(10, 7))
    sns.violinplot(data=df, x='Génération', y='Fitness',
                   alpha=0.6, inner='box')

    plt.title('Distribution de la Fitness - Première vs Dernière Génération', fontsize=14)
    plt.xlabel('Génération', fontsize=12)
    plt.ylabel('Fitness', fontsize=12)

    # Affichage du graphique
    plt.tight_layout()
    plt.show()

# Exemple d'appel de fonction
subset_data = {'fitness_history': training_data['fitness_history']}
plot_fitness_distribution(subset_data)

# %%
# Analyse de convergence
def plot_convergence_analysis(data):
    generations = range(len(data['best_fitness_per_gen']))
    best_fitness = data['best_fitness_per_gen']

    # Calcul du taux d'amélioration
    improvement_rate = [0]
    for i in range(1, len(best_fitness)):
        improvement = (best_fitness[i] - best_fitness[i-1]) / best_fitness[i-1] * 100
        improvement_rate.append(improvement)

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

    # Plot du taux d'amélioration
    ax1.plot(generations[1:], improvement_rate[1:], 'g-', label='Taux d\'amélioration')
    ax1.set_title('Taux d\'amélioration par Génération', fontsize=14)
    ax1.set_xlabel('Génération', fontsize=12)
    ax1.set_ylabel('Taux d\'amélioration (%)', fontsize=12)
    ax1.grid(True, alpha=0.3)

    # Plot de la moyenne mobile du taux d'amélioration
    window = 5
    rolling_mean = pd.Series(improvement_rate).rolling(window=window).mean()
    ax1.plot(generations, rolling_mean, 'r--',
             label=f'Moyenne mobile ({window} générations)')
    ax1.legend()

    # Plot de la progression relative
    relative_progress = [(f - best_fitness[0]) / best_fitness[0] * 100
                        for f in best_fitness]
    ax2.plot(generations, relative_progress, 'b-', label='Progression relative')
    ax2.set_title('Progression Relative de la Meilleure Fitness', fontsize=14)
    ax2.set_xlabel('Génération', fontsize=12)
    ax2.set_ylabel('Amélioration relative (%)', fontsize=12)
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

plot_convergence_analysis(training_data)

# %%
# Heatmap de diversité
def plot_diversity_heatmap(data):
    # Calculer la matrice de diversité
    pop_size = len(data['fitness_history'][0])
    num_generations = len(data['fitness_history'])
    diversity_matrix = np.zeros((num_generations, pop_size))

    for gen, fitness_list in enumerate(data['fitness_history']):
        sorted_fitness = sorted(fitness_list, reverse=True)
        diversity_matrix[gen] = sorted_fitness

    plt.figure(figsize=(15, 8))

    # Créer le heatmap et garder la référence pour la colorbar
    heatmap = sns.heatmap(diversity_matrix.T,
                         cmap='viridis',
                         xticklabels=10,
                         yticklabels=5,
                         cbar_kws={'label': 'Fitness'})  # Ajouter le label directement dans cbar_kws

    plt.title('Heatmap de la Distribution des Fitness', fontsize=14)
    plt.xlabel('Génération', fontsize=12)
    plt.ylabel('Individu (trié par fitness)', fontsize=12)

    plt.tight_layout()
    plt.show()

plot_diversity_heatmap(training_data)

# %%
# Statistiques de convergence
def print_convergence_stats(data):
    best_fitness = data['best_fitness_per_gen']
    avg_fitness = data['avg_fitness_per_gen']

    # Calculer les statistiques
    final_best = best_fitness[-1]
    final_avg = avg_fitness[-1]
    best_gen = np.argmax(best_fitness)

    # Calculer le temps de convergence (quand on atteint 90% du max)
    threshold = 0.9 * max(best_fitness)
    convergence_gen = next(
        (i for i, f in enumerate(best_fitness) if f >= threshold),
        len(best_fitness)
    )

    print("Statistiques de convergence:")
    print(f"Meilleure fitness finale: {final_best:.2f}")
    print(f"Fitness moyenne finale: {final_avg:.2f}")
    print(f"Génération de la meilleure fitness: {best_gen}")
    print(f"Génération de convergence (90%): {convergence_gen}")
    print(f"Amélioration totale: {((final_best/best_fitness[0])-1)*100:.2f}%")

print_convergence_stats(training_data)
# Out:
# Statistiques de convergence:
# Meilleure fitness finale: 2000.11
# Fitness moyenne finale: 784.87
# Génération de la meilleure fitness: 186
# Génération de convergence (90%): 0
# Amélioration totale: 2.03%
